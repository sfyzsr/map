# %%
import numpy as np
import pandas as pd
import cv2 as cv
import matplotlib as mpl
import matplotlib.pyplot as plt
# from scipy.interpolate import griddata
# from scipy.interpolate import RBFInterpolator
from tqdm import tqdm
# import open3d as o3d
import os
from pyquaternion import Quaternion
# from floorplan_utils import *
# from img_utils import *

# %%
def ralign(X, Y):
    m, n = X.shape

    mx = X.mean(1)
    my = Y.mean(1)

    Xc = X - mx[..., None]
    Yc = Y - my[..., None]

    sx = Xc.var(1).sum()
    sy = Yc.var(1).sum()

    Sxy = np.dot(Yc, Xc.T) / n

    S = np.ones(m)
    if np.linalg.det(Sxy) < 0:
        S[m - 1] = -1

    U, D, V = np.linalg.svd(Sxy)

    r = np.linalg.matrix_rank(Sxy)

    if r >= (m - 1):
        if r == m - 1:
            if np.linalg.det(U) * np.linalg.det(V) > 0:
                R = np.dot(U, V)
            else:
                s_ = S[m - 1]
                S[m - 1] = -1
                R = np.dot(U, np.dot(np.diag(S), V))
                S[m - 1] = s_
        else:
            R = np.dot(U, np.dot(np.diag(S), V))
    else:
        return (None, None, None, None)

    DS = np.dot(D, S)

    c = DS / sx
    t = my - c * np.dot(R, mx)

    e = sy - DS**2 / sx

    return R, c, t, e

# %%
mpl.rcParams['figure.figsize'] = [15, 15]

# %%
# data_root = '/home/lipeize/catkin_liosam/saves/'
# seqs = ['2023-02-02-18-52-57-seq6-f0', 
#         '2023-02-02-19-03-11-seq7-f0', 
#         '2023-02-02-19-12-55-seq8-f0', 
#         '2023-02-02-19-24-52-seq9-f1', 
#         '2023-02-02-19-35-47-seq10-f1',
#         '2023-02-02-19-46-24-seq11-f1']
# seq_idx = 0
data_root = '../data/'
seqs = ['filter_3','filter_6','filter_7','filter_9']
seq_idx = 2

# %% [markdown]
# Read LAST line of path file.

# %%
# with open(os.path.join(data_root, seqs[seq_idx], 'path.csv'), 'r') as f:
#     lines = f.read().splitlines()
#     last_line = lines[-1]
# path = last_line.split(',')
# path = np.load(data_root+seqs[seq_idx]+ '.npy')
# path = np.array(path[4:]).reshape([-1, 10])
# path = np.delete(path, 2, 1)
# path = path.astype(float)
# gt_path = path[:, 2:5]

df = pd.read_csv(data_root+seqs[seq_idx]+ '.csv')
df = df.sort_values(by=['secs','nsecs'])
path = df[['p_x', 'p_y','p_z']].values
path = np.array(path)
path = path.astype(float)
path.shape
# Out:
# (370, 3)

# %%
seq_duration = (path[-1, 1] - path[0, 1]) / 1e9
print(seq_duration)
# Out:
# 6.423489758744836e-10

# %%
plt.plot(path[:, 0], path[:, 1])
plt.axis('equal')
# Out:
# (-15.78797698020935,
#  38.637289762496955,
#  -34.007373332977295,
#  25.163102626800537)

# %%
# corners_gt = np.array([[5.944540, 39.708279, -0.520508],
#  [25.561304, 9.863537, -0.466914],
#  [-3.859824, -6.034390, 0.085863],
# [12.924220, -30.910660, 0.450827]])

# corners_gt = np.array([[-14.550963, 11.512155, -0.848353], 
#                        [11.399657, 30.526108, -0.594791], 
#                        [14.986525, 7.845741, -1.207359], 
#                        [3.370856, -4.656131, -1.457701]])

# x = corners_gt[:,0]
# y = corners_gt[:,1]
# plt.scatter(x, y)

# corners_gt = np.array([[2.959888, 46.526699, 0.384468],
# [39.828835, -7.806488, -1.175075],
# [15.363974, -38.455940, 1.737134],
# [-8.250896, -8.302032, 2.217922]])


# corners_gt = np.array([[2.959888, 46.526699, 0.384468],
#  [39.828835, -7.806488, -1.175075],
#  [15.363974, -38.455940, 1.737134],
# [-8.250896, -8.302032, 2.217922]])

corners_gt = np.array([[42.599022, 26.993732, 1.733781],
[32.778751, -15.451105, 2.164089],
 [-19.657387, -34.432613, 3.437793],
[-12.088697, 1.861743, -0.671927]])

# Point index picked: 86976 (real: 86976) - [6.472130, 39.414200, 0.478048]
# Point index picked: 64020 (real: 64020) - [33.364693, 14.977477, 0.279529]
# Point index picked: 15466 (real: 15466) - [15.117744, -38.073227, 3.057659]
# Point index picked: 37695 (real: 37695) - [-8.708307, -8.988010, 0.862633]

# %%
# corners_map = np.array([[523, -431, 0], 
#                         [1427, -365, 0], 
#                         [1165, -960, 0], 
#                         [693, -1088, 0]])

corners_map = np.array([[1006, 2350, 0], 
                        [4343, 1463, 0], 
                        [7627, 4494, 0], 
                        [4714, 5291, 0]])

# corners_map = np.array([
# [194,532, 0], 
# [1170,260, 0], 
# [2137,1187, 0], 
# [1282,1428, 0]])
# corners_map[:,0] = corners_map[:,0] - 9362/2 
# corners_map[:,1] = 6623/2 - corners_map[:,1]
corners_map[:,1] = corners_map[:,1]*-1
# corners_map = corners_map/80
# corners_map = corners_map /72/39.37 * 100
corners_map
# Out:
# array([[ 1006, -2350,     0],
#        [ 4343, -1463,     0],
#        [ 7627, -4494,     0],
#        [ 4714, -5291,     0]])

# %%
print(np.linalg.norm(corners_gt[0] - corners_gt[1]))
print(np.linalg.norm(corners_gt[1] - corners_gt[2]))
print(np.linalg.norm(corners_gt[2] - corners_gt[3]))
print(np.linalg.norm(corners_gt[3] - corners_gt[0]))
# Out:
# 43.56818880151978
# 55.78053904534021
# 37.30221366419473
# 60.23413410600626

# %%
print(np.linalg.norm(corners_map[0] - corners_map[1]))
print(np.linalg.norm(corners_map[1] - corners_map[2]))
print(np.linalg.norm(corners_map[2] - corners_map[3]))
print(np.linalg.norm(corners_map[3] - corners_map[0]))
print("/scale")
corners_map = corners_map /200/39.37 * 100
print(np.linalg.norm(corners_map[0] - corners_map[1]))
print(np.linalg.norm(corners_map[1] - corners_map[2]))
print(np.linalg.norm(corners_map[2] - corners_map[3]))
print(np.linalg.norm(corners_map[3] - corners_map[0]))

x = 9362/200/39.37 * 100
y = 6623/200/39.37 * 100

x
# Out:
# 3452.8738754840147
# 4468.96151247692
# 3020.062582133026
# 4732.731241048872
# /scale
# 43.85158592181883
# 56.755924720306325
# 38.35487150283243
# 60.10580697293462
# 118.8976377952756

# %%
alignment = ralign(corners_gt.T, corners_map.T)
print(alignment)
# Out:
# (array([[-0.45860159, -0.88779698,  0.03874396],
#        [ 0.88790026, -0.45600211,  0.06078827],
#        [-0.03630032,  0.06227837,  0.99739846]]), 1.010085514601122, array([ 56.43923487, -55.48026168,  -0.94770039]), 1.132152334229204)

# %%
q = Quaternion(matrix=alignment[0])

# %%
gt_matched = []
# for i in gt_path:
for i in path:
    gt_matched.append(q.rotate(i) + alignment[2])
gt_matched = np.array(gt_matched)

# %%
maxx= 9362/200/39.37 * 100
maxy= -6623/200/39.37 * 100
fig, ax = plt.subplots()
im = plt.imread("../2.png")
im = ax.imshow(im, extent=[0, maxx, maxy, 0])
ax.plot(gt_matched[:, 0], gt_matched[:, 1], c='r')

# %%
ts = path[:,1] / 1e7 - 1.675346097874434204e11
out = np.hstack((ts.reshape((-1, 1)), gt_matched[:,0:2]))
np.save(os.path.join(data_root, seqs[seq_idx], 'gt.npy'), out)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\AERO\Desktop\ML map\matching\seq7.ipynb Cell 17 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/seq7.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> ts = path[:,1] / 1e7 - 1.675346097874434204e11
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/seq7.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> out = np.hstack((ts.reshape((-1, 1)), gt_matched[:,0:2]))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/seq7.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> np.save(os.path.join(data_root, seqs[seq_idx], 'gt.npy'), out)
#
# File c:\Python39\lib\site-packages\numpy\lib\npyio.py:542, in save(file, arr, allow_pickle, fix_imports)
#     540     if not file.endswith('.npy'):
#     541         file = file + '.npy'
# --> 542     file_ctx = open(file, "wb")
#     544 with file_ctx as fid:
#     545     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/filter_7\\gt.npy'

# %%
from scipy import interpolate
fx = interpolate.interp1d(out[:,0], out[:,1])
fy = interpolate.interp1d(out[:,0], out[:,2])
ts_new = np.arange(out[0,0], out[-1,0], 10)
out_interpolate = np.hstack((ts_new.reshape((-1, 1)), fx(ts_new).reshape((-1, 1)), fy(ts_new).reshape((-1, 1))))
np.save(os.path.join(data_root, seqs[seq_idx], 'gt_interpolate.npy'), out_interpolate)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\AERO\Desktop\ML map\matching\GT_transform_batch2_seq6.ipynb Cell 18 in 6
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> ts_new = np.arange(out[0,0], out[-1,0], 10)
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> out_interpolate = np.hstack((ts_new.reshape((-1, 1)), fx(ts_new).reshape((-1, 1)), fy(ts_new).reshape((-1, 1))))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> np.save(os.path.join(data_root, seqs[seq_idx], 'gt_interpolate.npy'), out_interpolate)
#
# File c:\Python39\lib\site-packages\numpy\lib\npyio.py:542, in save(file, arr, allow_pickle, fix_imports)
#     540     if not file.endswith('.npy'):
#     541         file = file + '.npy'
# --> 542     file_ctx = open(file, "wb")
#     544 with file_ctx as fid:
#     545     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/3\\gt_interpolate.npy'

# %%
fig, ax = plt.subplots()
im = plt.imread("/mnt/workdir/huawei_ips/F0_corrected_72.png")
im = ax.imshow(im, extent=[0, maxx, maxy, 0])
ax.plot(out_interpolate[:, 1], out_interpolate[:, 2], c='r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\AERO\Desktop\ML map\matching\GT_transform_batch2_seq6.ipynb Cell 19 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = plt.subplots()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> im = plt.imread("/mnt/workdir/huawei_ips/F0_corrected_72.png")
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> im = ax.imshow(im, extent=[0, 84.1, -59.4, 0])
#       <a href='vscode-notebook-cell:/c%3A/Users/AERO/Desktop/ML%20map/matching/GT_transform_batch2_seq6.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> ax.plot(out_interpolate[:, 1], out_interpolate[:, 2], c='r')
#
# File c:\Python39\lib\site-packages\matplotlib\pyplot.py:2407, in imread(fname, format)
#    2405 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2406 def imread(fname, format=None):
# -> 2407     return matplotlib.image.imread(fname, format)
#
# File c:\Python39\lib\site-packages\matplotlib\image.py:1501, in imread(fname, format)
#    1499                 response = io.BytesIO(response.read())
#    1500             return imread(response, format=ext)
# -> 1501 with img_open(fname) as image:
#    1502     return (_pil_png_to_float_array(image)
#    1503             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1504             pil_to_array(image))
#
# File c:\Python39\lib\site-packages\PIL\ImageFile.py:109, in ImageFile.__init__(self, fp, filename)
#     105 self.decodermaxblock = MAXBLOCK
#     107 if isPath(fp):
#     108     # filename
# --> 109     self.fp = open(fp, "rb")
#     110     self.filename = fp
#     111     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/workdir/huawei_ips/F0_corrected_72.png'

# %%
out
